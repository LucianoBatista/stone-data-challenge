# %%
import pandas as pd

# %%
portfolio_geral_df = pd.read_csv("data/portfolio_geral.csv")
portfolio_geral_df
# Out:
#                               contrato_id dt_ref_portfolio    safra  \
# 0        356c02706c8e74b15004bb5964ade6bb       2022-03-01  2020-06
# 1        1eb0e13f83f336146227ccc9efb08c47       2022-03-01  2020-07
# 2        8b03675f597974ca96f06648e96af6d4       2022-03-01  2020-08
# 3        4207c25cdd13aba5a05ae348e889d798       2022-03-01  2021-03
# 4        7dfdca96b6ff0dd844e5e130aee88b30       2022-03-01  2020-11
# ...                                   ...              ...      ...
# 8061001  b532ce3583bf083b58dcbb3156e9a6fb       2020-10-04  2020-09
# 8061002  c5cce1cc49025572c7378279c1469923       2020-10-04  2020-05
# 8061003  67348b340a082aa77a67b7431cc91145       2020-10-31  2020-06
# 8061004  835d1f4def59389b5fbd64eaf195ece6       2020-09-14  2020-02
# 8061005  e4753f517397dec57e638d49b982fc96       2020-10-17  2020-03
#
#                              nr_documento status_contrato dt_contrato  \
# 0        b0871d4e0d72afd1d44381e5b2453cb2         Settled  2020-06-24
# ...

# %%
df = portfolio_geral_df[
    portfolio_geral_df["contrato_id"] == "0d823ddff1839eb938dccc68586ae365"
].sort_values(["dt_ref_portfolio"])

# %%
portfolio_geral_df.dtypes
# Out:
# contrato_id                    object
# dt_ref_portfolio               object
# safra                          object
# nr_documento                   object
# status_contrato                object
# dt_contrato                    object
# dt_desembolso                  object
# dt_vencimento                  object
# dt_wo                          object
# prazo                         float64
# vlr_desembolsado              float64
# vlr_tarifa                    float64
# juros_mes                     float64
# juros_diario                  float64
# perc_retencao                 float64
# vlr_pgto_realizado            float64
# vlr_pgto_esperado             float64
# vlr_saldo_devedor             float64
# vlr_saldo_devedor_esperado    float64
# dsp                             int64
# dspp                            int64
# flag_transacao                  int64
# dtype: object

# %%
portfolio_geral_df["status_contrato"].value_counts()
# Out:
# Active                   5642791
# Settled                  2239468
# Suspended                 173373
# DisbursementConfirmed       2427
# DisbursementRequested       1797
# Accepted                    1150
# Name: status_contrato, dtype: int64

# %%
portfolio_geral_df["dsp"].hist(bins=20)
# Out:
# <AxesSubplot:>

# %%
portfolio_geral_df["dspp"].hist(bins=20)
# Out:
# <AxesSubplot:>

# %%
portfolio_tpv = pd.read_csv("data/portfolio_tpv.csv")

# %%
# ta aglomerado no dia
portfolio_tpv
# Out:
#                              nr_documento  dt_transacao  qtd_transacoes  \
# 0        7f0464355620bc7c137b3546eb90867a      20210505               4
# 1        7f0464355620bc7c137b3546eb90867a      20210506              20
# 2        7f0464355620bc7c137b3546eb90867a      20210507              17
# 3        7f0464355620bc7c137b3546eb90867a      20210508              29
# 4        7f0464355620bc7c137b3546eb90867a      20210509              35
# ...                                   ...           ...             ...
# 4408592  1addbacfc5ca5fa417aef899d2cd849d      20210325               2
# 4408593  1addbacfc5ca5fa417aef899d2cd849d      20210327               2
# 4408594  1addbacfc5ca5fa417aef899d2cd849d      20210329               2
# 4408595  1addbacfc5ca5fa417aef899d2cd849d      20210330               1
# 4408596  1addbacfc5ca5fa417aef899d2cd849d      20210409               1
#
#          vlr_tpv
# 0          116.5
# 1          537.0
# 2          440.0
# 3         1328.0
# ...

# %%
df = (
    portfolio_geral_df[
        portfolio_geral_df["nr_documento"] == "7f0464355620bc7c137b3546eb90867a"
    ]
    .sort_values(["dt_ref_portfolio"])
    .head(100)
)

# %%
portfolio_comunicados = pd.read_csv("data/portfolio_comunicados.csv")
portfolio_comunicados
# Out:
#                              contrato_id dt_ref_portfolio   data_acao  \
# 0       0d823ddff1839eb938dccc68586ae365       2021-01-16  2021-01-18
# 1       c2f8a21671dbaeaa4157e03682c639e1       2021-05-22  2021-05-24
# 2       e19a222c233d46ff4984489c13aa1b98       2020-09-15  2020-09-15
# 3       c24fc7630fe5b89928ba9478c2cdd9b2       2021-07-20  2021-07-20
# 4       0abe9c2f21e941f2bd3b086277e33ebc       2020-12-26  2020-12-28
# ...                                  ...              ...         ...
# 403735  c7dc25f386144912b90500ffd45e71c5       2020-10-19  2020-10-19
# 403736  76c9917af4fa0810bd2e5638523a1a30       2020-06-19  2020-06-19
# 403737  724407e5260f93c0e3ea385564bdc731       2021-06-28  2021-06-28
# 403738  42b5d6594f79ee300ce0966c894b04c5       2021-09-26  2021-09-28
# 403739  83ead8d8ac5cf8e60759058ec3588bdb       2021-02-07  2021-02-09
#
#        tipo_acao                   acao        status
# 0            HSM     campanhaobservacao          LIDO
# ...

# %%
portfolio_comunicados[
    portfolio_comunicados["contrato_id"] == "0d823ddff1839eb938dccc68586ae365"
].sort_values(["dt_ref_portfolio"])
# Out:
#                              contrato_id dt_ref_portfolio   data_acao  \
# 166406  0d823ddff1839eb938dccc68586ae365       2020-10-10  2020-10-12
# 117554  0d823ddff1839eb938dccc68586ae365       2020-10-10  2020-10-12
# 249405  0d823ddff1839eb938dccc68586ae365       2020-10-18  2020-10-20
# 62581   0d823ddff1839eb938dccc68586ae365       2020-10-18  2020-10-20
# 349268  0d823ddff1839eb938dccc68586ae365       2020-10-24  2020-10-26
# ...                                  ...              ...         ...
# 62576   0d823ddff1839eb938dccc68586ae365       2021-06-12  2021-06-14
# 78266   0d823ddff1839eb938dccc68586ae365       2021-06-19  2021-06-21
# 160612  0d823ddff1839eb938dccc68586ae365       2021-06-19  2021-06-21
# 185534  0d823ddff1839eb938dccc68586ae365       2021-06-26  2021-06-28
# 262569  0d823ddff1839eb938dccc68586ae365       2021-06-26  2021-06-28
#
#        tipo_acao                acao        status
# 166406     EMAIL  campanhaobservacao  NAO ENTREGUE
# ...

# %%
portfolio_comunicados[portfolio_comunicados["status"] == "NAO ENTREGUE"][
    "acao"
].value_counts()
# Out:
# campanhaobservacao        100984
# campanhaparcelamento       42527
# campanhaboletoquitado      32347
# campanhaprenegativacao     10095
# campanhanegativacao         5254
# Name: acao, dtype: int64

# %%
portfolio_comunicados["tipo_acao"].value_counts()
# Out:
# HSM      201870
# EMAIL    201870
# Name: tipo_acao, dtype: int64

# %%
portfolio_clientes = pd.read_csv("data/portfolio_clientes.csv")

# %%
portfolio_clientes
# Out:
#                            nr_documento tipo_empresa                 cidade  \
# 0      094aaed740bbd7fcddb6c678c18d883a           PJ                Caucaia
# 1      eaade7915611fcdcbba747e3a83365c6           PF       Cidade Ocidental
# 2      1f21958fd296f1b04a1f0c2658913856          MEI                 Manaus
# 3      fcdfe15db4520db1a1fe8b6a72878655          MEI  São Bernardo do Campo
# 4      ba57e8837452b5e0114d7e273de039b4           PJ          Foz do Iguaçu
# ...                                 ...          ...                    ...
# 14400  bfed2a37a79957ea53cf1b70d467e4f1           PJ                   Bage
# 14401  fbcba6437b248dfce69ac494b4c266f1          MEI                 Osasco
# 14402  29b16c64a0d582d0162c8346bcbab1b0           PJ             São Carlos
# 14403  2ba5b641cad668157ede5a32fe1f3b00          MEI               Imbituba
# 14404  a00dd98d3d874de9d73e154aa02d5ca0           PF    Barra dos Coqueiros
#
#       estado         subsegmento               segmento
# ...
