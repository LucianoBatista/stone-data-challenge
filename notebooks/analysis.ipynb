# %%
import pandas as pd

# %%
df = pd.read_csv("data/to_analysis.csv")
df
# Out:
#                             contrato_id  total_success_dsp5  \
# 0      000180509391a5ac66ff83cae603ffb8                   1
# 1      000c35a61297edadc2842f6d5b4028e1                   4
# 2      bcd244d93204f40ca32f55fa2b06ca1f                   2
# 3      000dcdc93a545ee45a1aee85ef85c34a                  11
# 4      0014cccd47b66a47af4e62c4dcbe95f1                   3
# ...                                 ...                 ...
# 12197  fff4bf15d5b48a5c1bda798ea77290d1                   1
# 12198  fff6edc99168d63a10ea51a7f808ff38                   3
# 12199  fffb0d6ec51d163ca8c69900f748d61b                   5
# 12200  fffb47b9ce3835c85513ef5b19165f6e                   1
# 12201  fffc9af28349e8ded3af8e2dcbf9c3bc                   0
#
#        total_success_dsp10  total_success_dsp15  total_success_dsp30  \
# 0                        1                    0                    0
# 1                        1                    1                    1
# ...

# %% [markdown]
# # Score vs total de sucesso vs total de comunicação

# %%
df.columns
# Out:
# Index(['contrato_id', 'total_success_dsp5', 'total_success_dsp10',
#        'total_success_dsp15', 'total_success_dsp30', 'total_success_dsp60',
#        'total_success_dsp90', 'prop_success_dsp5', 'prop_success_dsp10',
#        'prop_success_dsp15', 'prop_success_dsp30', 'prop_success_dsp60',
#        'prop_success_dsp90', 'total_success_dspp15', 'total_success_dspp30',
#        'total_success_dspp45', 'prop_success_dspp15', 'prop_success_dspp30',
#        'prop_success_dspp45', 'score_dsp', 'score_dspp', 'get_entregue',
#        'get_lido', 'get_nao_entregue', 'vlr_saldo_devedor_esperado',
#        'nr_documento', 'tipo_empresa', 'cidade', 'estado', 'subsegmento',
#        'segmento', '('qtd_transacoes', 'mean')', '('qtd_transacoes', 'min')',
#        '('qtd_transacoes', 'max')', '('qtd_transacoes', 'median')',
#        '('qtd_transacoes', 'sum')', '('vlr_tpv', 'mean')',
#        '('vlr_tpv', 'min')', '('vlr_tpv', 'max')', '('vlr_tpv', 'median')',
#        '('vlr_tpv', 'sum')'],
# ...

# %%
totals = [column for column in df.columns if column.startswith("total_")]

score_success_action = df[
    [
        "nr_documento",
        "score_dsp",
        *totals,
        "get_entregue",
        "get_lido",
        "get_nao_entregue",
    ]
]

# %%
score_success_action.sort_values("score_dsp", ascending=False)
# Out:
#                            nr_documento  score_dsp  total_success_dsp5  \
# 6117   67853c8b604c9b7b99960b69079cfdec        1.0                   1
# 9203   d28fb90a87838fb5de2206642c35b5f1        1.0                   3
# 9228   01d6b0c45f3608d2d0fb8b7539c8769d        1.0                   2
# 9223   a414329608e8e033661ad6657ad5b2d0        1.0                   1
# 3585   3695e78a5145478e13dcc55cdf1e9971        1.0                   1
# ...                                 ...        ...                 ...
# 12134  5b34dd71c6df23b4ec3e60f659dc6735        NaN                   0
# 12137  762f1b9d1029c64ec82e3bb1edaad2f5        NaN                   0
# 12158  af8a40489eeef72513dd1a0f67483c5c        NaN                   0
# 12159  e33a444620bc517821b8b2a592490800        NaN                   0
# 12201  cee34a02820f1120a5046f416a3e0967        NaN                   0
#
#        total_success_dsp10  total_success_dsp15  total_success_dsp30  \
# ...

# %%
comunicados = pd.read_csv("data/portfolio_comunicados.csv")
comunicados
# Out:
#                              contrato_id dt_ref_portfolio   data_acao  \
# 0       0d823ddff1839eb938dccc68586ae365       2021-01-16  2021-01-18
# 1       c2f8a21671dbaeaa4157e03682c639e1       2021-05-22  2021-05-24
# 2       e19a222c233d46ff4984489c13aa1b98       2020-09-15  2020-09-15
# 3       c24fc7630fe5b89928ba9478c2cdd9b2       2021-07-20  2021-07-20
# 4       0abe9c2f21e941f2bd3b086277e33ebc       2020-12-26  2020-12-28
# ...                                  ...              ...         ...
# 403735  c7dc25f386144912b90500ffd45e71c5       2020-10-19  2020-10-19
# 403736  76c9917af4fa0810bd2e5638523a1a30       2020-06-19  2020-06-19
# 403737  724407e5260f93c0e3ea385564bdc731       2021-06-28  2021-06-28
# 403738  42b5d6594f79ee300ce0966c894b04c5       2021-09-26  2021-09-28
# 403739  83ead8d8ac5cf8e60759058ec3588bdb       2021-02-07  2021-02-09
#
#        tipo_acao                   acao        status
# 0            HSM     campanhaobservacao          LIDO
# ...

# %%
comunicados[comunicados["contrato_id"] == "be7e0b3fed136849f48ca6771eda8ca5"]
# Out:
#                              contrato_id dt_ref_portfolio   data_acao  \
# 8756    be7e0b3fed136849f48ca6771eda8ca5       2021-05-01  2021-05-03
# 36524   be7e0b3fed136849f48ca6771eda8ca5       2021-10-11  2021-10-11
# 62114   be7e0b3fed136849f48ca6771eda8ca5       2021-10-17  2021-10-19
# 69718   be7e0b3fed136849f48ca6771eda8ca5       2021-10-11  2021-10-11
# 130244  be7e0b3fed136849f48ca6771eda8ca5       2021-04-21  2021-04-21
# 134490  be7e0b3fed136849f48ca6771eda8ca5       2021-10-02  2021-10-04
# 168585  be7e0b3fed136849f48ca6771eda8ca5       2021-02-09  2021-02-09
# 173471  be7e0b3fed136849f48ca6771eda8ca5       2021-02-09  2021-02-09
# 251844  be7e0b3fed136849f48ca6771eda8ca5       2021-04-21  2021-04-21
# 359210  be7e0b3fed136849f48ca6771eda8ca5       2021-05-01  2021-05-03
# 365555  be7e0b3fed136849f48ca6771eda8ca5       2021-10-02  2021-10-04
# 398321  be7e0b3fed136849f48ca6771eda8ca5       2021-10-17  2021-10-19
#
#        tipo_acao                  acao        status
# ...

# %%
geral = pd.read_csv("data/portfolio_geral.csv")
geral
# Out:
#                               contrato_id dt_ref_portfolio    safra  \
# 0        356c02706c8e74b15004bb5964ade6bb       2022-03-01  2020-06
# 1        1eb0e13f83f336146227ccc9efb08c47       2022-03-01  2020-07
# 2        8b03675f597974ca96f06648e96af6d4       2022-03-01  2020-08
# 3        4207c25cdd13aba5a05ae348e889d798       2022-03-01  2021-03
# 4        7dfdca96b6ff0dd844e5e130aee88b30       2022-03-01  2020-11
# ...                                   ...              ...      ...
# 8061001  b532ce3583bf083b58dcbb3156e9a6fb       2020-10-04  2020-09
# 8061002  c5cce1cc49025572c7378279c1469923       2020-10-04  2020-05
# 8061003  67348b340a082aa77a67b7431cc91145       2020-10-31  2020-06
# 8061004  835d1f4def59389b5fbd64eaf195ece6       2020-09-14  2020-02
# 8061005  e4753f517397dec57e638d49b982fc96       2020-10-17  2020-03
#
#                              nr_documento status_contrato dt_contrato  \
# 0        b0871d4e0d72afd1d44381e5b2453cb2         Settled  2020-06-24
# ...

# %%
geral[geral["nr_documento"] == "01d6b0c45f3608d2d0fb8b7539c8769d"]
# Out:
#                               contrato_id dt_ref_portfolio    safra  \
# 78559    be7e0b3fed136849f48ca6771eda8ca5       2022-01-29  2021-01
# 89945    be7e0b3fed136849f48ca6771eda8ca5       2021-02-16  2021-01
# 172767   be7e0b3fed136849f48ca6771eda8ca5       2021-10-25  2021-01
# 186815   be7e0b3fed136849f48ca6771eda8ca5       2022-02-25  2021-01
# 186990   be7e0b3fed136849f48ca6771eda8ca5       2021-11-05  2021-01
# ...                                   ...              ...      ...
# 8022011  be7e0b3fed136849f48ca6771eda8ca5       2022-02-12  2021-01
# 8025168  be7e0b3fed136849f48ca6771eda8ca5       2022-03-31  2021-01
# 8026102  be7e0b3fed136849f48ca6771eda8ca5       2022-03-07  2021-01
# 8026496  be7e0b3fed136849f48ca6771eda8ca5       2022-04-02  2021-01
# 8026519  be7e0b3fed136849f48ca6771eda8ca5       2021-04-29  2021-01
#
#                              nr_documento status_contrato dt_contrato  \
# 78559    01d6b0c45f3608d2d0fb8b7539c8769d          Active  2021-01-21
# ...
